# %%
import time
import win32gui
import numpy as np

import mss
import mss.tools
from PIL import Image, ImageOps

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from cloningCNN import CloningCNN, ResNet

from torch.distributions import Categorical

from pynput.keyboard import Key, Controller
import matplotlib.pyplot as plt

# %% [markdown]
# # Define RL environment for the game window

# %%
class GameEnv:
    def __init__(self, windowName, inputInterval, usingResNet=False):
        self.gameBbox = self.getWindowBbox(windowName)
        self.capper = mss.mss()
        self.capNum = 0
        self.downsamplingMethod = Image.NEAREST
        self.usingResNet = usingResNet
        
        self.captureWindow = None
        self.prevGoldPixels = None
        
        self.keyboard = Controller()
        self.keyCodes = {0:Key.up, 1:Key.right, 2:Key.down, 3:Key.left}
        self.inputInterval = inputInterval
        
    def getWindowBbox(self, windowName):
        gameWindow = win32gui.FindWindow(None, windowName)
        if gameWindow == 0:
            print("Could not find game window for \"" + windowName + "\". Exiting.")
            exit()
        
        bbox = list(win32gui.GetWindowRect(gameWindow))
        # fix idiosyncrasies of win32gui window rect acquisition
        bbox[0] += 8
        bbox[1] += 31
        width = bbox[2]-bbox[0]
        height = bbox[3]-bbox[1]
        # return a 'monitor' object in the format that the mss library wants
        return {'top': bbox[1], 'left': bbox[0], 'width': width-8, 'height': height-8}
    
    def quickRestart(self):
        for key in [Key.esc, Key.up, Key.up, Key.up, Key.right]:
            self.keyboard.press(key)
            self.keyboard.release(key)
            time.sleep(0.1)
        time.sleep(2)
    
    def reset(self):
        self.quickRestart()
        initScreen, initGoldPixels, lvlDone, heartPixels = self.getScreenInfo()
        self.prevGoldPixels = initGoldPixels
        self.prevHeartPixels = heartPixels
        self.captureWindow = [initScreen for _ in range(4)]
        
        return self.captureWindow
    
    def getScreenInfo(self):
        # capture screen and downscale to 180x180
        self.capNum += 1
        screenCap = self.capper.grab(self.gameBbox)
        img = Image.frombytes('RGB', screenCap.size, screenCap.bgra, 'raw', 'BGRX')
        heartPixels = []
        if self.usingResNet:
            final = img.resize((224,224), self.downsamplingMethod)
            # check for reward indicators
            goldPixels = np.array(final.crop((201,7,218,15))) == 255 # resnet version
            lvlPixels = np.array(final.crop((219,219,224,224))) == 255 # resnet version
            for pixelCoord in [153,158,170,175]: # resnet version
                heartPixels.append(np.array(final.crop((pixelCoord,10,pixelCoord+1,11))).sum())
            print("WARNING: LEVEL INDICATOR BROKEN FOR RESNET")
        else:
            padded = ImageOps.expand(img, (30,38,26,18))
            resized = padded.resize((360,360), self.downsamplingMethod)
            final = resized.resize((180,180), self.downsamplingMethod)
            # check for reward indicators
            goldPixels = np.array(final.crop((158,11,170,17))) == 255 # white pixels of gold meter in top right
            levelDone = np.array(final.crop((173,174,174,176))).sum() != 1530
            for pixelCoord in [121,125,134,138]:
                heartPixels.append(np.array(final.crop((pixelCoord,12,pixelCoord+1,13))).sum())

        return (final, goldPixels.astype(int), levelDone, heartPixels)
    
    def step(self, action):
        done = False
        reward = 0
        
        # carry out action
        keyPress = self.keyCodes[action]
        self.keyboard.press(keyPress)
        self.keyboard.release(keyPress)
        
        # wait, then get new game capture
        time.sleep(self.inputInterval)
        screen, goldPixels, lvlDone, heartPixels = self.getScreenInfo()
        
        if lvlDone: # wait a bit then recheck the screen, helps prevent false level finishes
            time.sleep(1)
            screen, goldPixels, lvlDone, heartPixels = self.getScreenInfo()
             
        # check if got reward
        if np.sum(np.abs(goldPixels - self.prevGoldPixels)) != 0: # gold value changed
            reward += 10
        if lvlDone: # beat level 1
            reward += 400
            done = True
            
        # check for damage or dead
        for heartIndex, heartPixel in enumerate(heartPixels):
            if self.prevHeartPixels[heartIndex] != 115 and heartPixel == 115:
                reward -= 8
#                 print ("lost heart {}. penalty applied.".format(heartIndex))
        if heartPixels[0] == 115:
            done = True
            
        # update state variables
        self.prevGoldPixels = goldPixels
        self.prevHeartPixels = heartPixels
        self.captureWindow.pop()
        self.captureWindow.insert(0, screen)
        
        return (self.captureWindow, reward, done)

# %% [markdown]
# # Define Agent with CNN

# %%
class CloningAgent:
    def __init__(self, model, normTransform, gamma=0.99):
        if torch.cuda.is_available() :
            self.device = torch.device('cuda')
            print("using cuda")
        else:
            self.device = torch.device('cpu')
        self.model = model.to(device=self.device, dtype=torch.float32)
        model.eval()
        self.normTransform = normTransform
        
        self.saved_log_probs = []
        self.rewards = []
        self.gamma = gamma
        
        self.eps = np.finfo(np.float32).eps.item()
        self.optimizer = optim.Adam(self.model.parameters(), lr=1e-3)
        
    def getActionScores(self, state, verbose=False):
        tensors = [self.normTransform(cap).unsqueeze(0) for cap in state]
        x = torch.cat((tensors[0],tensors[1],tensors[2],tensors[3]), dim=1)
        x = x.to(device=self.device, dtype=torch.float32)# move to device, e.g. GPU
        actionScores = self.model(x)   #.data.cpu().numpy()[0]
        if verbose:
            print(actionScores)
        return actionScores

    def sampleAction(self, state, verbose=False):
        scores = self.getActionScores(state, verbose)
        probs = F.softmax(scores, dim=1)
        m = Categorical(probs)
        action = m.sample()
        self.saved_log_probs.append(m.log_prob(action))
        return action.item()
    
    def finishEpisode(self):
        R = 0
        policy_loss = []
        rewards = []
        for r in self.rewards[::-1]:
            R = r + self.gamma * R
            rewards.insert(0, R)
        rewards = torch.tensor(rewards).to(device=self.device, dtype=torch.float32)
        rewards = (rewards - rewards.mean()) / (rewards.std() + self.eps)
        for log_prob, reward in zip(self.saved_log_probs, rewards):
            policy_loss.append(-log_prob * reward)
        self.optimizer.zero_grad()
        policy_loss = torch.cat(policy_loss).sum()
        policy_loss.backward()
        self.optimizer.step()
        del self.rewards[:]
        del self.saved_log_probs[:]

# %% [markdown]
# # Initialize agent and environment
# Load a model for the agent to use and its cached normalization statistics.

# %%
usingResNet = False

if usingResNet:
    model = ResNet()
    model.load_state_dict(torch.load("models/ResnetQuadsVal80.pt"))
else:
    model = CloningCNN('deeper', dropout=0.5, inChannels=12)
    model.load_state_dict(torch.load('models/DeeperQuadsVal79.pt', map_location=lambda storage, loc: storage))
#     model.reinitializeFC(numReinitialize=2)
    #     model.load_state_dict(torch.load("models/DeeperQuadsVal79.pt"))
#     model.load_state_dict(torch.load("models/PG_deeperquads_pre_2/300.pt"))

# %%
if usingResNet:
    meanImage = np.load("data/stats/dsetMean_ResNet.npy")
    stdImage = np.load("data/stats/dsetStd_ResNet.npy")
else:
    meanImage = np.load("data/stats/dsetMean.npy")
    stdImage = np.load("data/stats/dsetStd.npy")
plt.subplot(121)
plt.imshow(np.array(np.round(meanImage), dtype=np.uint8))
plt.title("Mean image")
plt.subplot(122)
plt.imshow(np.array(np.round(stdImage), dtype=np.uint8))
plt.title("Std image")
# get channel means formatted like tensors
channelMeans = meanImage.transpose((2,0,1)).mean(axis=(1,2)) / 255
channelStds = meanImage.transpose((2,0,1)).std(axis=(1,2)) / 255

transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(channelMeans, channelStds)
        ])

# %%
windowName = "Crypt of the NecroDancer"

env = GameEnv(windowName, 0.36, usingResNet)
agent = CloningAgent(model, transform, gamma=0.99)

# %% [markdown]
# # Train the model using policy gradients

# %%
running_reward = 15
log_interval = 20
rewardsOverTime = []
modelsFolder = "models/normal/PG_deeperquads_preinit2"

# %%
print("Move the windows taskbar!")
time.sleep(4) # activate the game window during this
for i_episode in range(102):
    state = env.reset()
    t, timeSinceReward, totalReward = 0, 0, 0
    while timeSinceReward < 70:  # Don't infinite loop while learning
        action = agent.sampleAction(state, verbose=(t%100==0))
        state, reward, done = env.step(action)
        if reward != 0:
            timeSinceReward = 0
            totalReward += reward
#             print("Got reward {}.".format(reward))
        agent.rewards.append(reward)
        aborted = win32gui.GetWindowText(win32gui.GetForegroundWindow()) != windowName
        if aborted or done:
            break
        timeSinceReward += 1
        t += 1
    if aborted:
        print("Game window no longer active. Stopping training.")
        break
    
    print('finishing episode...')
    running_reward = running_reward * 0.95 + totalReward * 0.05
    agent.finishEpisode()
    rewardsOverTime.append(totalReward)
    
    print('Episode {}\tLast reward: {:5d}\tAverage reward: {:.2f}'.format(
            i_episode, totalReward, running_reward))
    if i_episode % log_interval == 0:
        torch.save(agent.model.state_dict(), "{}/{}.pt".format(modelsFolder, i_episode))
# Out:
# Move the windows taskbar!
# tensor([[-0.4021, -0.6783,  1.8085, -1.6911]])
# tensor([[-0.7362, -1.8677,  6.4105,  6.2492]])
# finishing episode...
# Episode 0	Last reward:   118	Average reward: 20.15
# tensor([[-0.7148, -0.1517,  1.3059, -1.0596]])
# tensor([[-3.4140,  4.1119, -2.9928, -6.4987]])
# finishing episode...
# Episode 1	Last reward:    34	Average reward: 20.84
# tensor([[-1.1160, -0.2660,  2.0432, -1.2103]])
# tensor([[-2.6227,  4.0274, -4.9038, -1.3507]])
# finishing episode...
# Episode 2	Last reward:    88	Average reward: 24.20
# tensor([[-1.5492,  0.6141,  1.3852, -1.1342]])
# tensor([[ 1.2423, -0.6056, -1.2779,  0.5202]])
# finishing episode...
# Episode 3	Last reward:    84	Average reward: 27.19
# tensor([[-1.6138,  0.9327,  1.1263, -0.8320]])
# tensor([[-4.6943,  5.1144, -7.4395,  0.2685]])
# finishing episode...
# Episode 4	Last reward:    38	Average reward: 27.73
# tensor([[-1.5891,  0.8317,  1.1037, -0.7263]])
# tensor([[-1.0886,  3.6945, -5.4437, -3.3804]])
# finishing episode...
# Episode 5	Last reward:    88	Average reward: 30.74
# tensor([[-1.5960,  0.7923,  1.1400, -0.6384]])
# tensor([[-3.4402,  2.1455, -0.5850, -1.8163]])
# finishing episode...
# Episode 6	Last reward:    88	Average reward: 33.61
# tensor([[-1.5089,  0.8708,  0.9661, -0.6150]])
# finishing episode...
# Episode 7	Last reward:     0	Average reward: 31.93
# tensor([[-1.4937,  0.9844,  0.5676, -0.3183]])
# finishing episode...
# Episode 8	Last reward:    20	Average reward: 31.33
# tensor([[-1.6490,  0.9654,  0.9981, -0.6251]])
# tensor([[-2.1790,  4.1030, -4.6258, -8.0605]])
# finishing episode...
# Episode 9	Last reward:   104	Average reward: 34.96
# tensor([[-1.6957,  0.8472,  1.4464, -0.8709]])
# tensor([[ 0.0947,  0.3561, -3.6187,  0.5655]])
# finishing episode...
# Episode 10	Last reward:    50	Average reward: 35.72
# tensor([[-1.6773,  0.6302,  1.8929, -0.7387]])
# tensor([[ 2.2959, -3.0903, -1.8121,  2.7042]])
# finishing episode...
# Episode 11	Last reward:    64	Average reward: 37.13
# tensor([[-1.7183,  0.2801,  2.5553, -0.3870]])
# finishing episode...
# Episode 12	Last reward:    28	Average reward: 36.67
# tensor([[-1.4043, -0.1232,  3.0434,  0.1581]])
# tensor([[ 3.0921, -3.9756, -0.8498,  5.4378]])
# finishing episode...
# Episode 13	Last reward:    40	Average reward: 36.84
# tensor([[-1.0360, -0.5711,  3.3924,  0.5972]])
# tensor([[-3.4747,  5.4310, -4.5862, -6.0548]])
# finishing episode...
# Episode 14	Last reward:    40	Average reward: 37.00
# tensor([[-0.6916, -0.8797,  3.5782,  0.4748]])
# tensor([[  3.2804,  -5.2006,  -1.4752,  12.1397]])
# finishing episode...
# Episode 15	Last reward:    30	Average reward: 36.65
# tensor([[-0.4323, -1.1802,  3.8363,  0.4694]])
# tensor([[ 0.5764, -0.6583,  0.1698,  1.8119]])
# finishing episode...
# Episode 16	Last reward:    40	Average reward: 36.82
# tensor([[-0.0419, -1.4702,  3.9018,  0.5140]])
# finishing episode...
# Episode 17	Last reward:    30	Average reward: 36.47
# tensor([[ 0.1833, -1.6761,  3.9765,  0.4985]])
# finishing episode...
# Episode 18	Last reward:    22	Average reward: 35.75
# tensor([[ 0.4946, -1.9240,  3.9955,  0.5538]])
# tensor([[-0.7891,  3.7851, -6.0444, -4.5312]])
# finishing episode...
# Episode 19	Last reward:    40	Average reward: 35.96
# tensor([[ 0.4989, -2.1295,  4.3005,  0.4867]])
# tensor([[ 2.6891, -0.7224, -1.1481, -2.9493]])
# finishing episode...
# Episode 20	Last reward:    30	Average reward: 35.67
# tensor([[ 0.3995, -2.2122,  4.5430,  0.4160]])
# tensor([[ 0.3867, -0.3883, -1.5480,  2.7448]])
# finishing episode...
# Episode 21	Last reward:    40	Average reward: 35.88
# tensor([[ 0.3856, -2.4525,  4.9020,  0.4046]])
# tensor([[ 2.6012, -1.9541, -3.3832,  0.8408]])
# finishing episode...
# Episode 22	Last reward:    40	Average reward: 36.09
# tensor([[ 0.6542, -2.7293,  5.0646,  0.5133]])
# tensor([[ 1.7067, -1.1035, -0.1058, -0.1754]])
# finishing episode...
# Episode 23	Last reward:    14	Average reward: 34.98
# tensor([[ 0.9559, -3.0900,  5.2619,  0.7069]])
# tensor([[ 3.5869, -2.8007,  0.3923, -1.5106]])
# finishing episode...
# Episode 24	Last reward:    40	Average reward: 35.23
# tensor([[ 1.4869, -3.6031,  5.4455,  0.9920]])
# finishing episode...
# Episode 25	Last reward:    12	Average reward: 34.07
# tensor([[ 2.0865, -4.1939,  5.4064,  1.6334]])
# finishing episode...
# Episode 26	Last reward:    22	Average reward: 33.47
# tensor([[ 3.1104, -4.8238,  4.4495,  2.2538]])
# finishing episode...
# Episode 27	Last reward:    40	Average reward: 33.80
# tensor([[ 4.1254, -5.2658,  3.3445,  1.9313]])
# finishing episode...
# Episode 28	Last reward:     0	Average reward: 32.11
# tensor([[ 5.5317, -5.7674,  1.3563,  1.7719]])
# finishing episode...
# Episode 29	Last reward:     0	Average reward: 30.50
# tensor([[ 6.7918, -6.5377, -0.4472,  1.2651]])
# finishing episode...
# Episode 30	Last reward:     0	Average reward: 28.98
# tensor([[ 7.9994, -7.5249, -1.7874,  0.8553]])
# finishing episode...
# Episode 31	Last reward:     0	Average reward: 27.53
# tensor([[ 9.1592, -8.5258, -3.5322,  0.5153]])
# finishing episode...
# Episode 32	Last reward:     0	Average reward: 26.15
# tensor([[ 10.2388,  -9.4848,  -5.8521,   0.3336]])
# finishing episode...
# Episode 33	Last reward:     0	Average reward: 24.84
# tensor([[ 11.4304, -10.5453,  -7.4275,   0.1591]])
# finishing episode...
# Episode 34	Last reward:     0	Average reward: 23.60
# tensor([[ 12.5947, -11.5874,  -8.8357,  -0.0287]])
# finishing episode...
# Episode 35	Last reward:     0	Average reward: 22.42
# tensor([[ 13.7233, -12.4870, -10.7992,  -0.1322]])
# finishing episode...
# Episode 36	Last reward:     0	Average reward: 21.30
# tensor([[ 14.8864, -13.5247, -12.0024,  -0.2997]])
# finishing episode...
# Episode 37	Last reward:     0	Average reward: 20.23
# tensor([[ 15.9441, -14.4101, -13.5130,  -0.4590]])
# finishing episode...
# Episode 38	Last reward:     0	Average reward: 19.22
# tensor([[ 16.9366, -15.1902, -15.2285,  -0.5452]])
# finishing episode...
# Episode 39	Last reward:     0	Average reward: 18.26
# tensor([[ 17.9162, -16.0243, -16.6206,  -0.7323]])
# finishing episode...
# Episode 40	Last reward:     0	Average reward: 17.35
# tensor([[ 18.8404, -16.7891, -18.0610,  -0.6597]])
# finishing episode...
# Episode 41	Last reward:     0	Average reward: 16.48
# tensor([[ 19.8105, -17.6550, -19.1222,  -0.6967]])
# finishing episode...
# Episode 42	Last reward:     0	Average reward: 15.66
# tensor([[ 20.6700, -18.3823, -20.2690,  -0.7400]])
# finishing episode...
# Episode 43	Last reward:     0	Average reward: 14.87
# tensor([[ 21.4723, -19.0952, -21.3561,  -0.6962]])
# finishing episode...
# Episode 44	Last reward:     0	Average reward: 14.13
# tensor([[ 22.2181, -19.7707, -22.3587,  -0.6376]])
# finishing episode...
# Episode 45	Last reward:     0	Average reward: 13.42
# tensor([[ 22.9091, -20.4018, -23.2905,  -0.5695]])
# finishing episode...
# Episode 46	Last reward:     0	Average reward: 12.75
# tensor([[ 23.5479, -20.9868, -24.1564,  -0.4966]])
# finishing episode...
# Episode 47	Last reward:     0	Average reward: 12.12
# tensor([[ 24.0724, -21.4392, -25.0698,  -0.3279]])
# finishing episode...
# Episode 48	Last reward:     0	Average reward: 11.51
# tensor([[ 24.6174, -21.9325, -25.8171,  -0.2349]])
# finishing episode...
# Episode 49	Last reward:     0	Average reward: 10.93
# tensor([[ 25.1616, -22.4517, -26.3529,  -0.2074]])
# finishing episode...
# Episode 50	Last reward:     0	Average reward: 10.39
# tensor([[ 25.6358, -22.8886, -26.8803,  -0.1321]])
# finishing episode...
# Episode 51	Last reward:     0	Average reward: 9.87
# tensor([[ 26.0627, -23.2866, -27.4345,  -0.0271]])
# finishing episode...
# Episode 52	Last reward:     0	Average reward: 9.37
# tensor([[ 26.3704, -23.5339, -28.0905,   0.0882]])
# finishing episode...
# Episode 53	Last reward:     0	Average reward: 8.91
# tensor([[ 26.7857, -23.9399, -28.3683,   0.0847]])
# finishing episode...
# Episode 54	Last reward:     0	Average reward: 8.46
# tensor([[ 27.0473, -24.1461, -29.0032,   0.2104]])
# finishing episode...
# Episode 55	Last reward:     0	Average reward: 8.04
# tensor([[ 27.4200, -24.5235, -29.1826,   0.2214]])
# finishing episode...
# Episode 56	Last reward:     0	Average reward: 7.64
# tensor([[ 27.6164, -24.6819, -29.6116,   0.3184]])
# finishing episode...
# Episode 57	Last reward:     0	Average reward: 7.25
# tensor([[ 27.9311, -24.9774, -29.8407,   0.2849]])
# finishing episode...
# Episode 58	Last reward:     0	Average reward: 6.89
# tensor([[ 28.0982, -25.1181, -30.2263,   0.4010]])
# finishing episode...
# Episode 59	Last reward:     0	Average reward: 6.55
# tensor([[ 28.3635, -25.3710, -30.3958,   0.3656]])
# finishing episode...
# Episode 60	Last reward:     0	Average reward: 6.22
# tensor([[ 28.4850, -25.4552, -30.8077,   0.4642]])
# finishing episode...
# Episode 61	Last reward:     0	Average reward: 5.91
# tensor([[ 28.7107, -25.6861, -30.8806,   0.4357]])
# finishing episode...
# Episode 62	Last reward:     0	Average reward: 5.61
# tensor([[ 28.8188, -25.7680, -31.1458,   0.5350]])
# finishing episode...
# Episode 63	Last reward:     0	Average reward: 5.33
# tensor([[ 29.0326, -25.9701, -31.2432,   0.4855]])
# finishing episode...
# Episode 64	Last reward:     0	Average reward: 5.07
# tensor([[ 29.1446, -26.0617, -31.4758,   0.5116]])
# finishing episode...
# Episode 65	Last reward:     0	Average reward: 4.81
# tensor([[ 29.2653, -26.1687, -31.6278,   0.5330]])
# finishing episode...
# Episode 66	Last reward:     0	Average reward: 4.57
# tensor([[ 29.4184, -26.3422, -31.7633,   0.6315]])
# finishing episode...
# Episode 67	Last reward:     0	Average reward: 4.34
# tensor([[ 29.4748, -26.3547, -31.8920,   0.5703]])
# finishing episode...
# Episode 68	Last reward:     0	Average reward: 4.13
# tensor([[ 29.5755, -26.4540, -31.9342,   0.5884]])
# finishing episode...
# Episode 69	Last reward:     0	Average reward: 3.92
# tensor([[ 29.6371, -26.5012, -32.1046,   0.6060]])
# finishing episode...
# Episode 70	Last reward:     0	Average reward: 3.72
# tensor([[ 29.7032, -26.5544, -32.2311,   0.6145]])
# finishing episode...
# Episode 71	Last reward:     0	Average reward: 3.54
# tensor([[ 29.7149, -26.5310, -32.5010,   0.6950]])
# finishing episode...
# Episode 72	Last reward:     0	Average reward: 3.36
# tensor([[ 29.8456, -26.6960, -32.3191,   0.6454]])
# finishing episode...
# Episode 73	Last reward:     0	Average reward: 3.19
# tensor([[ 29.8321, -26.6355, -32.6497,   0.7169]])
# finishing episode...
# Episode 74	Last reward:     0	Average reward: 3.03
# tensor([[ 29.8987, -26.7167, -32.5950,   0.7259]])
# finishing episode...
# Episode 75	Last reward:     0	Average reward: 2.88
# tensor([[ 30.0255, -26.8535, -32.4950,   0.6667]])
# finishing episode...
# Episode 76	Last reward:     0	Average reward: 2.74
# tensor([[ 30.0510, -26.8775, -32.5705,   0.6782]])
# finishing episode...
# Episode 77	Last reward:     0	Average reward: 2.60
# tensor([[ 30.1556, -26.9950, -32.7480,   0.8286]])
# finishing episode...
# Episode 78	Last reward:     0	Average reward: 2.47
# tensor([[ 30.1232, -26.9420, -32.6616,   0.6917]])
# finishing episode...
# Episode 79	Last reward:     0	Average reward: 2.35
# tensor([[ 30.1599, -26.9753, -32.6722,   0.6971]])
# finishing episode...
# Episode 80	Last reward:     0	Average reward: 2.23
# tensor([[ 30.1990, -27.0082, -32.7135,   0.6990]])
# finishing episode...
# Episode 81	Last reward:     0	Average reward: 2.12
# tensor([[ 30.2246, -27.0311, -32.7458,   0.7037]])
# finishing episode...
# Episode 82	Last reward:     0	Average reward: 2.01
# tensor([[ 30.2486, -27.0572, -32.7774,   0.7195]])
# finishing episode...
# Episode 83	Last reward:     0	Average reward: 1.91
# tensor([[ 30.2689, -27.0706, -32.8015,   0.7120]])
# finishing episode...
# Episode 84	Last reward:     0	Average reward: 1.82
# tensor([[ 30.2929, -27.1017, -32.8339,   0.7455]])
# finishing episode...
# Episode 85	Last reward:     0	Average reward: 1.73
# tensor([[ 30.2943, -27.0952, -32.8416,   0.7222]])
# finishing episode...
# Episode 86	Last reward:     0	Average reward: 1.64
# tensor([[ 30.2497, -27.0280, -33.0311,   0.7862]])
# finishing episode...
# Episode 87	Last reward:     0	Average reward: 1.56
# tensor([[ 30.3933, -27.2091, -33.0319,   0.8689]])
# finishing episode...
# Episode 88	Last reward:     0	Average reward: 1.48
# tensor([[ 30.3370, -27.1333, -32.8953,   0.7302]])
# finishing episode...
# Episode 89	Last reward:     0	Average reward: 1.41
# tensor([[ 30.2768, -27.0548, -33.0737,   0.7986]])
# finishing episode...
# Episode 90	Last reward:     0	Average reward: 1.33
# tensor([[ 30.2948, -27.0751, -33.0551,   0.8045]])
# finishing episode...
# Episode 91	Last reward:     0	Average reward: 1.27
# tensor([[ 30.3796, -27.1694, -32.9407,   0.7326]])
# finishing episode...
# Episode 92	Last reward:     0	Average reward: 1.20
# tensor([[ 30.2991, -27.0614, -33.1938,   0.8032]])
# finishing episode...
# Episode 93	Last reward:     0	Average reward: 1.14
# tensor([[ 30.3069, -27.0684, -33.2036,   0.8047]])
# finishing episode...
# Episode 94	Last reward:     0	Average reward: 1.09
# tensor([[ 30.4154, -27.2317, -33.0294,   0.8214]])
# finishing episode...
# Episode 95	Last reward:     0	Average reward: 1.03
# tensor([[ 30.3986, -27.1883, -32.9729,   0.7417]])
# finishing episode...
# Episode 96	Last reward:     0	Average reward: 0.98
# tensor([[ 30.4153, -27.2012, -32.9856,   0.7392]])
# finishing episode...
# Episode 97	Last reward:     0	Average reward: 0.93
# tensor([[ 30.4103, -27.2034, -32.9891,   0.7552]])
# finishing episode...
# Episode 98	Last reward:     0	Average reward: 0.89
# tensor([[ 30.4088, -27.1968, -33.0214,   0.7449]])
# finishing episode...
# Episode 99	Last reward:     0	Average reward: 0.84
# tensor([[ 30.3464, -27.1171, -33.1620,   0.8121]])
# finishing episode...
# Episode 100	Last reward:     0	Average reward: 0.80
# tensor([[ 30.4479, -27.2501, -33.0356,   0.7932]])
# finishing episode...
# Episode 101	Last reward:     0	Average reward: 0.76

# %%
with open("{}/rewards.txt".format(modelsFolder), "w+") as rewardsFile:
    for reward in rewardsOverTime:
        rewardsFile.write("{}\n".format(reward))

# %%
plt.plot(rewardsOverTime)
# plt.axis([0, 135, -40, 200])
plt.show()

# %%
avgs = []
N = 30
for i in range(N):
    avgs.append(None)
    
for i in range(N, len(rewardsOverTime[:102])):
    avgs.append(sum(rewardsOverTime[i-N:i])/N)
plt.figure(dpi=300)
plt.plot(rewardsOverTime[:102],label="Reward")
plt.plot(avgs,label="Running Mean (30 eps)")
plt.legend(loc="upper left")
plt.title("Reward Per Episode")
# plt.axis([0, 120, -40, 200])
plt.savefig('demos/normal/PG_deeperquads_preinit2.png')
plt.show()

# %% [markdown]
# # Run the model greedily after training

# %%
print("Move the windows taskbar!")
with torch.no_grad():
    time.sleep(4) # activate the game window during this
    state = env.reset()
    while win32gui.GetWindowText(win32gui.GetForegroundWindow()) == windowName: # exit on window unfocus
        actionScores = agent.getActionScores(state)
#         print(actionScores)
        action = np.argmax(actionScores.data.cpu().numpy()[0])
        state, reward, done = env.step(action)
#         time.sleep(0.4)
        if reward != 0:
            print("Got reward {}.".format(reward))
        
print("Game window no longer active. Exiting.")
# Out:
# Move the windows taskbar!
# Got reward 410.
# Game window no longer active. Exiting.
