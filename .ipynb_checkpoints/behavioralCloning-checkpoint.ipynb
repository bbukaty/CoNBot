# %%
import torch 
import torchvision
import torch.nn as nn
import torch.optim as optim

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.nn.functional as F  # useful stateless functions

import numpy as np
from PIL import Image
import torch.utils.data.dataset as datautil


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

# %%
# need to do this twice for it to work for some reason
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# # Load preprocessed dataset mean and standard deviation

# %%
dset_mean = np.load("stats/dsetMean.npy")
dset_std = np.load("stats/dsetStd.npy")

plt.subplot(121)
plt.imshow(np.array(np.round(dset_mean), dtype=np.uint8))
plt.title("Mean image")
plt.subplot(122)
plt.imshow(np.array(np.round(dset_std), dtype=np.uint8))
plt.title("Std image")
# Out:
# Text(0.5,1,'Std image')

# %% [markdown]
# Pytorch expects the data shape to be CxHxW (instead of the current HxWxC) so we reshape the mean and std image here, then use them to calculate the means for the three color channels. For images in the training data, this transposition is handled when the dataset object applies the ToTensor() transformation.

# %%
dset_mean = np.transpose(dset_mean, (2,0,1))
dset_std = np.transpose(dset_std, (2,0,1))
print(dset_mean.shape, dset_std.shape)
# Out:
# (3, 180, 180) (3, 180, 180)

# %% [markdown]
# Finally, calculate the mean and std over the three image channels.

# %%
channel_means = dset_mean.mean(axis=(1,2)) / 255
channel_stds = dset_mean.std(axis=(1,2)) / 255 #TODO: just conver to tensor so that you don't have to do this division manually

print("Per-channel means:")
print(channel_means)
print("Per-channel stds:")
print(channel_stds)
# Out:
# Per-channel means:
# [0.1064527  0.07207663 0.04764687]
# Per-channel stds:
# [0.1276396 0.0965984 0.0777558]

# %% [markdown]
# # Initialize dataset and data loader objects
# Use the channel mean and std to define a normalization transform which our dataset object will apply to each of its images upon loading them.

# %%
image_transform = transforms.Compose([
    transforms.ToTensor()
#     transforms.Normalize(channel_means, channel_stds)
])

dataset = datasets.DatasetFolder(root='classes/normalized', extensions=['npy'], loader=np.load, transform=image_transform)
# train_dataset = datasets.ImageFolder(root='classes/downscaled', transform=image_transform)
num_train = len(dataset)
print("Training set has {} examples.".format(num_train))

num_val = num_train//10

permutation = np.random.RandomState(seed=0).permutation(num_train)

val_dataset = datautil.Subset(dataset, permutation[:num_val])
train_dataset = datautil.Subset(dataset, permutation[num_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=128,
                                           sampler=sampler.SubsetRandomSampler(range(num_train-num_val)))

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=128,
                                           sampler=sampler.SubsetRandomSampler(range(num_val)))
# Out:
# ----------------------------------------------------------
# FileNotFoundError        Traceback (most recent call last)
# <ipython-input-6-451ee4eaee59> in <module>()
#       4 ])
#       5
# ----> 6 dataset = datasets.DatasetFolder(root='classes/numpy', extensions=['npy'], loader=np.load, transform=image_transform)
#       7 # train_dataset = datasets.ImageFolder(root='classes/images', transform=image_transform)
#       8 num_train = len(dataset)
#
# c:\miniconda3\lib\site-packages\torchvision\datasets\folder.py in __init__(self, root, loader, extensions, transform, target_transform)
#      73
#      74     def __init__(self, root, loader, extensions, transform=None, target_transform=None):
# ---> 75         classes, class_to_idx = find_classes(root)
#      76         samples = make_dataset(root, class_to_idx, extensions)
#      77         if len(samples) == 0:
#
# c:\miniconda3\lib\site-packages\torchvision\datasets\folder.py in find_classes(dir)
#      21
#      22 def find_classes(dir):
# ---> 23     classes = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]
#      24     classes.sort()
#      25     class_to_idx = {classes[i]: i for i in range(len(classes))}
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'classes/numpy'

# %%
dataiter = iter(train_loader)

images, labels = dataiter.next()

print(images[0].shape)
print(dset_mean.shape)

plt.imshow((images[0].numpy() * dset_std/255 + dset_mean/255).transpose(1,2,0))

# plt.imshow((images[0].numpy() * channel_stds.reshape((3,1,1)) + channel_means.reshape((3,1,1))).transpose(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 180, 180])
# (3, 180, 180)

# %% [markdown]
# # Define training and validation functions

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 50000

print('using device:', device)

def flatten(x):
    N = x.shape[0] # read in N, C, H, W
    return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# We need to wrap `flatten` function in a module in order to stack it
# in nn.Sequential
class Flatten(nn.Module):
    def forward(self, x):
        return flatten(x)
# Out:
# using device: cuda

# %%
def check_model_accuracy(loader, model, name): 
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('%s set: Got %d / %d correct (%.2f)' % (name, num_correct, num_samples, 100 * acc))

# %%
def train_model(model, optimizer, epochs=1):
    """
    Train a model using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(train_loader):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            if t % print_every == 0:
                print('Iteration %d, loss = %.4f' % (t, loss.item()))
                check_model_accuracy(train_loader, model, 'Train')
                check_model_accuracy(val_loader, model, 'Val')
                print()

# %% [markdown]
# # Define model

# %%
hidden_layer_size = 4000
learning_rate = 1e-3

num_classes = 4

model = nn.Sequential(
    nn.Conv2d(3, 32, 6, stride=3, padding=9), # 32x64x64
    nn.ReLU(),
    nn.Conv2d(32, 16, 3, stride=1, padding=1), # 16x64x64
    nn.ReLU(),
    nn.Conv2d(16, 16, 3, stride=2, padding=0), # 16x32x32
    nn.ReLU(),
#     nn.Conv2d(32, 16, 3, padding=1),
#     nn.ReLU(),
#     nn.Conv2d(16, 16, 3, padding=1),
#     nn.ReLU(),
    Flatten(),
    nn.Linear(16*32*32, num_classes),
)

# you can use Nesterov momentum in optim.SGD
# optimizer = optim.SGD(model.parameters(), lr=learning_rate,
#                      momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters())

# %% [markdown]
# # Train on the dataset!

# %%
train_model(model, optimizer, epochs=30)
# Out:
# Iteration 0, loss = 1.3904
# Train set: Got 1342 / 4248 correct (31.59)
# Val set: Got 145 / 472 correct (30.72)
#
# Iteration 0, loss = 0.9653
# Train set: Got 2453 / 4248 correct (57.74)
# Val set: Got 241 / 472 correct (51.06)
#
# Iteration 0, loss = 0.7857
# Train set: Got 2976 / 4248 correct (70.06)
# Val set: Got 272 / 472 correct (57.63)
#
# Iteration 0, loss = 0.6253
# Train set: Got 3285 / 4248 correct (77.33)
# Val set: Got 293 / 472 correct (62.08)
#
# Iteration 0, loss = 0.5200
# Train set: Got 3416 / 4248 correct (80.41)
# Val set: Got 318 / 472 correct (67.37)
#
# Iteration 0, loss = 0.4388
# Train set: Got 3492 / 4248 correct (82.20)
# Val set: Got 327 / 472 correct (69.28)
#
# Iteration 0, loss = 0.4194
# Train set: Got 3637 / 4248 correct (85.62)
# Val set: Got 336 / 472 correct (71.19)
#
# Iteration 0, loss = 0.3364
# Train set: Got 3734 / 4248 correct (87.90)
# Val set: Got 341 / 472 correct (72.25)
#
# Iteration 0, loss = 0.3515
# Train set: Got 3785 / 4248 correct (89.10)
# Val set: Got 350 / 472 correct (74.15)
#
# Iteration 0, loss = 0.2906
# Train set: Got 3770 / 4248 correct (88.75)
# Val set: Got 356 / 472 correct (75.42)
#
# Iteration 0, loss = 0.1727
# Train set: Got 3860 / 4248 correct (90.87)
# Val set: Got 362 / 472 correct (76.69)
#
# Iteration 0, loss = 0.2211
# Train set: Got 3883 / 4248 correct (91.41)
# Val set: Got 349 / 472 correct (73.94)
#
# Iteration 0, loss = 0.1937
# Train set: Got 3997 / 4248 correct (94.09)
# Val set: Got 370 / 472 correct (78.39)
#
# Iteration 0, loss = 0.1749
# Train set: Got 4036 / 4248 correct (95.01)
# Val set: Got 361 / 472 correct (76.48)
#
# Iteration 0, loss = 0.1284
# Train set: Got 3963 / 4248 correct (93.29)
# Val set: Got 364 / 472 correct (77.12)
#
# Iteration 0, loss = 0.0829
# Train set: Got 4075 / 4248 correct (95.93)
# Val set: Got 370 / 472 correct (78.39)
#
# Iteration 0, loss = 0.1448
# Train set: Got 4047 / 4248 correct (95.27)
# Val set: Got 382 / 472 correct (80.93)
#
# Iteration 0, loss = 0.1021
# Train set: Got 4096 / 4248 correct (96.42)
# Val set: Got 366 / 472 correct (77.54)
#
# Iteration 0, loss = 0.1344
# Train set: Got 4134 / 4248 correct (97.32)
# Val set: Got 368 / 472 correct (77.97)
#
# Iteration 0, loss = 0.0664
# Train set: Got 4133 / 4248 correct (97.29)
# Val set: Got 374 / 472 correct (79.24)
#
# Iteration 0, loss = 0.1184
# Train set: Got 4107 / 4248 correct (96.68)
# Val set: Got 375 / 472 correct (79.45)
#
# Iteration 0, loss = 0.0286
# Train set: Got 4172 / 4248 correct (98.21)
# Val set: Got 380 / 472 correct (80.51)
#
# Iteration 0, loss = 0.0651
# Train set: Got 4140 / 4248 correct (97.46)
# Val set: Got 370 / 472 correct (78.39)
#
# Iteration 0, loss = 0.0198
# Train set: Got 4174 / 4248 correct (98.26)
# Val set: Got 377 / 472 correct (79.87)
#
# Iteration 0, loss = 0.0358
# Train set: Got 4185 / 4248 correct (98.52)
# Val set: Got 374 / 472 correct (79.24)
#
# Iteration 0, loss = 0.0313
# Train set: Got 4187 / 4248 correct (98.56)
# Val set: Got 374 / 472 correct (79.24)
#
# Iteration 0, loss = 0.0510
# Train set: Got 4192 / 4248 correct (98.68)
# Val set: Got 385 / 472 correct (81.57)
#
# Iteration 0, loss = 0.0241
# Train set: Got 4216 / 4248 correct (99.25)
# Val set: Got 381 / 472 correct (80.72)
#
# Iteration 0, loss = 0.0220
# Train set: Got 4208 / 4248 correct (99.06)
# Val set: Got 378 / 472 correct (80.08)
#
# Iteration 0, loss = 0.0153
# Train set: Got 4221 / 4248 correct (99.36)
# Val set: Got 381 / 472 correct (80.72)
